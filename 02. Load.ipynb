# %%
# Load Payment

spark.sql("DROP TABLE IF EXISTS bronze_payments")
spark.sql("CREATE TABLE bronze_payments USING DELTA LOCATION '/delta/bronze_payments'")
# Out:
# Out[8]: DataFrame[]

# %%
# Load Trips

spark.sql("DROP TABLE IF EXISTS bronze_trips")
spark.sql("CREATE TABLE bronze_trips USING DELTA LOCATION '/delta/bronze_trips'")
# Out:
# Out[10]: DataFrame[]

# %%
# Load Stations

spark.sql("DROP TABLE IF EXISTS bronze_stations")
spark.sql("CREATE TABLE bronze_stations USING DELTA LOCATION '/delta/bronze_stations'")
# Out:
# Out[11]: DataFrame[]

# %%
# Load Riders

spark.sql("DROP TABLE IF EXISTS bronze_riders")
spark.sql("CREATE TABLE bronze_riders USING DELTA LOCATION '/delta/bronze_riders'")
# Out:
# Out[12]: DataFrame[]

# %%
# %sql

SELECT * FROM bronze_trips;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
